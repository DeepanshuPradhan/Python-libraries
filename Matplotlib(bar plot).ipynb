# %%
import matplotlib.pyplot as plt  
    
# x axis values  
x = [1,2,3]  
# corresponding y axis values  
y = [2,4,1]  

# plotting the points   
plt.plot(x,y)
    
# naming the x axis  
plt.xlabel('x - axis')  
# naming the y axis  
plt.ylabel('y - axis')  
    
# giving a title to my graph  
plt.title('Linear graph')  
    
# function to show the plot  
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,3,4])
y=x*2;
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,4,6,8,10]
plt.figure(figsize=(8,6))
plt.plot(x,y,marker='o',linestyle='-')
for i,(xi,yi) in enumerate(zip(x,y)):
    plt.annotate(f'({xi},{yi}',(xi,yi),textcoords="offset points",xytext=(0,10), ha='center')
   


plt.title('Line chart with annotations')
plt.xlabel("x aixs label")
plt.ylabel("y aixs label")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,3,4])
y=x*2;
plt.plot(x,y)
plt.xlabel("x aixs label")
plt.ylabel("y aixs label")
plt.title('multi line chart')  
plt.show()
plt.figure()
x1=[2,4,6,8]
y1=[3,5,7,9]
plt.plot(x1,y1,'-.')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,3,4])
y=x*2
plt.plot(x,y)
x1=[2,4,6,8]
y1=[3,5,7,9]
plt.plot(x1,y1,'-.')
plt.xlabel("x axis data")
plt.ylabel("y axis data")
plt.title("multiple plots")
plt.show()

# %%
import matplotlib.pyplot as plt
x=["python","C","c++","java"]
y=[85,70,60,82]
plt.xlabel("language",fontsize=20)
plt.ylabel("No.",fontsize=20)
plt.title("Program Graph",fontsize=20)
plt.bar(x,y)
plt.show()

# %%
plt.bar(x,y,width=0.4)
# Out:
# <BarContainer object of 4 artists>

# %%
c=["y","b","m","g"]
plt.bar(x,y,width=0.4,color=c)
# Out:
# <BarContainer object of 4 artists>

# %%
c=["y","b","m","g"]
plt.bar(x,y,width=0.4,color=c,align="edge")
# Out:
# <BarContainer object of 4 artists>

# %%
c=["y","b","m","g"]
plt.bar(x,y,width=0.4,color=c,edgecolor="r",linewidth=2,linestyle=":")
# Out:
# <BarContainer object of 4 artists>

# %%
c=["y","b","m","g"]
plt.bar(x,y,width=0.4,color=c,alpha=0.6)
# Out:
# <BarContainer object of 4 artists>

# %%
c=["y","b","m","g"]
plt.bar(x,y,width=0.4,color=c,alpha=0.6,label="python")
plt.legend()

# %%
import matplotlib.pyplot as plt
x=["python","C","c++","java"]
y=[85,70,60,82]
z=[20,30,40,50]
plt.xlabel("language",fontsize=20)
plt.ylabel("No.",fontsize=20)
plt.title("Program Graph",fontsize=20)
plt.bar(x,y,width=0.4,color="b",label="popular")
plt.bar(x,z,width=0.4,color="r",label="popular1")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=["python","C","c++","java"]
y=[85,70,60,82]
z=[20,30,40,50]

width=0.2
p=np.arange(len(x))
p1=[j+width for j in p]

plt.xlabel("language",fontsize=20)
plt.ylabel("No.",fontsize=20)
plt.title("Program Graph",fontsize=20)

plt.barh(p,y,width,color="b",label="popular")
plt.barh(p1,z,width,color="r",label="popular1")

plt.xticks(p+width/2,x,rotation=10)
plt.legend(loc="best")
plt.show()

# %%
import matplotlib.pyplot as plt
x=["python","C","c++","java"]
y=[85,70,60,82]
z=[20,30,40,50]
width=0.2

plt.xlabel("language")
plt.ylabel("No.")
plt.title("Program Graph")

plt.barh(x,y,width,color="b",label="popular")
plt.barh(x,z,width,color="r",label="popular1")

plt.legend()
plt.show()
