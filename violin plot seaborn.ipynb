# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
var=sns.load_dataset("tips")
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(x="day",y="total_bill",data=var,hue="time")
plt.show()

# %%
sns.violinplot(x="day",y="total_bill",data=var,linewidth=2,palette="Dark2")
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8120\3628107971.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="day",y="total_bill",data=var,linewidth=2,palette="Dark2")

# %%
sns.violinplot(x="day",y="total_bill",data=var,order=["Dinner","Lunch"])
plt.show()

# %%
sns.violinplot(x="day",y="total_bill",data=var,linewidth=2,palette="Dark2",saturation=0-4)
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8120\2787568937.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="day",y="total_bill",data=var,linewidth=2,palette="Dark2",saturation=0-4)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sns.violinplot(x="day",y="total_bill",data=var,linewidth=2,palette="Dark2",saturation=0-4)
#       2 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:1755, in violinplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, inner, split, width, dodge, gap, linewidth, linecolor, cut, gridsize, bw_method, bw_adjust, density_norm, common_norm, hue_norm, formatter, log_scale, native_scale, legend, scale, scale_hue, bw, inner_kws, ax, **kwargs)
#    1753 saturation = saturation if fill else 1
#    1754 p.map_hue(palette=palette, order=hue_order, norm=hue_norm, saturation=saturation)
# -> 1755 color = _default_color(
#    1756     ax.fill_between, hue, color,
#    1757     {k: v for k, v in kwargs.items() if k in ["c", "color", "fc", "facecolor"]},
#    1758     saturation=saturation,
#    1759 )
#    1760 linecolor = p._complement_color(linecolor, color, p._hue_map)
#    1762 density_norm, common_norm = p._violin_scale_backcompat(
#    1763     scale, scale_hue, density_norm, common_norm,
#    1764 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\utils.py:142, in _default_color(method, hue, color, kws, saturation)
#     139     scout.remove()
#     141 if saturation < 1:
# --> 142     color = desaturate(color, saturation)
#     144 return color
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\utils.py:165, in desaturate(color, prop)
#     163 # Check inputs
#     164 if not 0 <= prop <= 1:
# --> 165     raise ValueError("prop must be between 0 and 1")
#     167 # Get rgb tuple rep
#     168 rgb = to_rgb(color)
#
# ValueError: prop must be between 0 and 1

# %%
sns.violinplot(x="day",y="total_bill",data=var,linewidth=2,color="y")
plt.show()

# %%
sns.violinplot(x="day",y="total_bill",data=var,scale="width")
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8120\2024033682.py:1: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(x="day",y="total_bill",data=var,scale="width")

# %%
sns.violinplot(x="day",y="total_bill",data=var,inner="point")
plt.show()

# %%
sns.violinplot(y=var["total_bill"])
plt.show()
