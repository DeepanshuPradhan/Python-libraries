# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50,60,70,120,200]
plt.boxplot(x,labels=["python"],showmeans=True)
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_10360\3689618928.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(x,labels=["python"],showmeans=True)

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50,60,70]
x1=10,20,30,40,50,60,70]
y=[x,x1]
plt.boxplot(x,labels=["python"],showmeans=True)
plt.show()
