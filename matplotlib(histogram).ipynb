# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x=np.random.randint(10,60,(50))
print(x)
# Out:
# [23 57 19 30 27 22 52 38 32 11 53 37 15 47 36 52 38 53 42 16 33 27 11 27
#  14 56 25 45 16 46 11 56 52 53 46 15 59 39 56 26 56 29 46 51 54 16 30 18
#  31 26]

# %%
no=[23, 57, 19 ,30, 27, 22, 52, 38, 32 ,11 ,53, 37, 15 ,47, 36 ,52, 38, 53, 42 ,16 ,33, 27, 11, 27,
 14 ,56 ,25, 45, 16 ,46, 11 ,56 ,52, 53 ,46 ,15, 59, 39, 56, 26, 56 ,29, 46, 51 ,54 ,16, 30, 18,
 31, 26]
l=[10,20,30,40,50,60]
plt.hist(no,color="m",bins=12,edgecolor="r",label="python")
plt.title("DEEPANSHU")
plt.xlabel("libraries")
plt.ylabel("number")
plt.axvline(35,color="g",label="LINE")
plt.legend()
plt.gr
plt.show()
