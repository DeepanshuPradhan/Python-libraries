# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
area=[2,3,2,5,4]
area1=[7,3,1,5,4]
area2=[1,3,8,5,4]
l=["area","area1","area2"]
plt.stackplot(x,area,area1,area2 ,labels=l,colors=["r","g","m"])
plt.title("python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")  

plt.legend(loc=7)
plt.show()
