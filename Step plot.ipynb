# %%
import matplotlib.pyplot as plt
x=[1,2,8,4,5]
y=[3,5,7,9,5]
plt.step(x,y,color="g",marker="o",ms=10,mfc="y",label="stem plot")
plt.title("python")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.legend(loc=2)
plt.grid()
plt.show()
